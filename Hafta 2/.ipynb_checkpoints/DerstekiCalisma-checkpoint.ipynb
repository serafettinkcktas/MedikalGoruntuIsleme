# %%
# 3X3 BOYUTUNDA ORTALAMA FİLTRESİ 
import numpy as np
import cv2
from skimage import data
import matplotlib.pyplot as plt

# %%
mean_kernel = np.full((3,3),1/9)

print(mean_kernel)
# Out:
# [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]

# %%
image = data.cat()
plt.imshow(image)
